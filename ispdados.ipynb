# %%
import pandas as pd

# %%
import numpy as np

# %%
url = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'
df = pd.read_csv(url, encoding = 'latin1', sep = ';')
df.head()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# ...

# %%
df.tail()
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 38131   159    7  2026  2026m07    11     7  Cachoeiras de Macacu  3300803
# 38132   165    7  2026  2026m07    33     5           Mangaratiba  3302601
# 38133   166    7  2026  2026m07    33     5        Angra dos Reis  3300100
# 38134   167    7  2026  2026m07    43     5                Paraty  3303807
# 38135   168    7  2026  2026m07    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 38131  Interior           0  ...   3.0   0.0      21                      3
# 38132  Interior           2  ...   8.0   0.0      40                      1
# 38133  Interior           3  ...  21.0   3.0      96                      4
# 38134   Capital           1  ...   3.0   0.0      27                      2
# 38135  Interior           0  ...   0.0   0.0       4                      2
#
# ...

# %%
df.columns
# Out:
# Index(['cisp', 'mes', 'ano', 'mes_ano', 'aisp', 'risp', 'munic', 'mcirc',
#        'regiao', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli',
#        'hom_por_interv_policial', 'feminicidio', 'letalidade_violenta',
#        'tentat_hom', 'tentativa_feminicidio', 'lesao_corp_dolosa', 'estupro',
#        'hom_culposo', 'lesao_corp_culposa', 'roubo_transeunte',
#        'roubo_celular', 'roubo_em_coletivo', 'roubo_rua', 'roubo_veiculo',
#        'roubo_carga', 'roubo_comercio', 'roubo_residencia', 'roubo_banco',
#        'roubo_cx_eletronico', 'roubo_conducao_saque', 'roubo_apos_saque',
#        'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos',
#        'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38136 entries, 0 to 38135
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        38136 non-null  int64
#  1   mes                         38136 non-null  int64
#  2   ano                         38136 non-null  int64
#  3   mes_ano                     38136 non-null  str
#  4   aisp                        38136 non-null  int64
#  5   risp                        38136 non-null  int64
#  6   munic                       38136 non-null  str
#  7   mcirc                       38136 non-null  int64
#  8   regiao                      38136 non-null  str
#  9   hom_doloso                  38136 non-null  int64
#  10  lesao_corp_morte            38136 non-null  int64
#  11  latrocinio                  38136 non-null  int64
#  12  cvli                        38136 non-null  int64
# ...

# %%
df.describe()
# Out:
#                cisp           mes           ano          aisp          risp  \
# count  38136.000000  38136.000000  38136.000000  38136.000000  38136.000000
# mean      81.725010      6.439506   2014.443308     20.160373      3.869992
# std       48.320975      3.445469      6.774282     11.354494      2.011410
# min        1.000000      1.000000   2003.000000      1.000000      1.000000
# 25%       38.000000      3.000000   2009.000000     10.000000      2.000000
# 50%       78.000000      6.000000   2015.000000     20.000000      4.000000
# 75%      125.000000      9.000000   2020.000000     30.000000      6.000000
# max      168.000000     12.000000   2026.000000     43.000000      7.000000
#
#               mcirc    hom_doloso  lesao_corp_morte    latrocinio  \
# count  3.813600e+04  38136.000000      38136.000000  38136.000000
# mean   3.790895e+06      2.896554          0.028293      0.094137
# std    1.739417e+06      4.300161          0.180065      0.363543
# ...

# %%
df_furto_cel_dp = df.groupby('cisp')['furto_celular'].sum().reset_index()
df_furto_cel_dp = df_furto_cel_dp.sort_values(by='furto_celular',ascending = False)
df_furto_cel_dp
# Out:
#      cisp  furto_celular
# 12     16          26230
# 2       5          25737
# 10     14          19004
# 8      12          17630
# 0       1          16185
# ..    ...            ...
# 41     45             73
# 77     92             65
# 114   138             56
# 131   157             55
# 129   155             47
#
# [138 rows x 2 columns]

# %% [markdown]
# ## usando o inplace True

# %%
df_furto_cel_dp = df.groupby('cisp')['furto_celular'].sum().reset_index()
df_furto_cel_dp.sort_values(by='furto_celular',ascending = False, inplace = True)
df_furto_cel_dp
# Out:
#      cisp  furto_celular
# 12     16          26230
# 2       5          25737
# 10     14          19004
# 8      12          17630
# 0       1          16185
# ..    ...            ...
# 41     45             73
# 77     92             65
# 114   138             56
# 131   157             55
# 129   155             47
#
# [138 rows x 2 columns]

# %%
df_apreensao_menor_dp = df.groupby('cisp')['aaapai'].sum().reset_index()
df_apreensao_menor_dp = df_apreensao_menor_dp.sort_values(by= 'aaapai',ascending = False)
df_apreensao_menor_dp
# Out:
#      cisp  aaapai
# 104   126  3736.0
# 8      12  3667.0
# 10     14  3368.0
# 65     74  3355.0
# 12     16  3233.0
# ..    ...     ...
# 130   156    19.0
# 129   155    16.0
# 131   157    14.0
# 94    111    13.0
# 77     92    12.0
#
# [138 rows x 2 columns]

# %% [markdown]
# ## Formula do Agrupamento

# %%
df_roubo_veiculo_dp = df.groupby('cisp')['roubo_veiculo'].sum().reset_index()
df_roubo_veiculo_dp = df_roubo_veiculo_dp.sort_values(by = 'roubo_veiculo',ascending = False)
df_roubo_veiculo_dp
# Out:
#      cisp  roubo_veiculo
# 52     59          37866
# 57     64          32892
# 35     39          29753
# 23     27          27978
# 30     34          27596
# ..    ...            ...
# 77     92              8
# 116   140              8
# 115   139              7
# 113   137              6
# 114   138              2
#
# [138 rows x 2 columns]

# %% [markdown]
# ## Filtragem com .loc e query()

# %%
df_capital = df.loc[df['munic'] == 'Rio de Janeiro']
df_capital
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 38035    40    7  2026  2026m07     9     2  Rio de Janeiro  3304557  Capital
# 38036    41    7  2026  2026m07    18     2  Rio de Janeiro  3304557  Capital
# 38037    42    7  2026  2026m07    31     2  Rio de Janeiro  3304557  Capital
# 38038    43    7  2026  2026m07    27     2  Rio de Janeiro  3304557  Capital
# 38039    44    7  2026  2026m07     3     1  Rio de Janeiro  3304557  Capital
#
# ...

# %%
df_capital = df.query("munic == 'Rio de Janeiro'")
df_capital
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 38035    40    7  2026  2026m07     9     2  Rio de Janeiro  3304557  Capital
# 38036    41    7  2026  2026m07    18     2  Rio de Janeiro  3304557  Capital
# 38037    42    7  2026  2026m07    31     2  Rio de Janeiro  3304557  Capital
# 38038    43    7  2026  2026m07    27     2  Rio de Janeiro  3304557  Capital
# 38039    44    7  2026  2026m07     3     1  Rio de Janeiro  3304557  Capital
#
# ...

# %% [markdown]
# ## Filtragem + Agrupamento

# %%
df_bel = df.loc[df['munic'] == 'Belford Roxo']
df_bel

df_furto_cel_bel_dp = df_bel.groupby('cisp')['roubo_veiculo'].sum().reset_index()
df_furto_cel_bel_dp.sort_values(by='roubo_veiculo',ascending = False, inplace = True)
df_furto_cel_bel_dp
# Out:
#    cisp  roubo_veiculo
# 0    54          25018

# %% [markdown]
# ## Isin dicionario e Ano específico

# %%
munic_pedido = ['Belford Roxo', 'Nova Iguaçu', 'Queimados']
df_br_ni_qm = df.loc[(df['munic'].isin(munic_pedido)) & (df['ano'] == 2025)] #cada condição no seu parenteses
df_br_ni_qm                                                                  #se atentar a chave do loc
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp         munic    mcirc  \
# 35577    52    1  2025  2025m01    20     3   Nova Iguaçu  3303500
# 35579    54    1  2025  2025m01    39     3  Belford Roxo  3300456
# 35580    55    1  2025  2025m01    24     3     Queimados  3304144
# 35581    56    1  2025  2025m01    20     3   Nova Iguaçu  3303500
# 35583    58    1  2025  2025m01    20     3   Nova Iguaçu  3303500
# 35714    52    2  2025  2025m02    20     3   Nova Iguaçu  3303500
# 35716    54    2  2025  2025m02    39     3  Belford Roxo  3300456
# 35717    55    2  2025  2025m02    24     3     Queimados  3304144
# 35718    56    2  2025  2025m02    20     3   Nova Iguaçu  3303500
# 35720    58    2  2025  2025m02    20     3   Nova Iguaçu  3303500
# 35851    52    3  2025  2025m03    20     3   Nova Iguaçu  3303500
# 35853    54    3  2025  2025m03    39     3  Belford Roxo  3300456
# 35854    55    3  2025  2025m03    24     3     Queimados  3304144
# ...

# %% [markdown]
# ## Array e Numpy - calculos e estatísticas

# %%
array_furto_cel_dp = np.array(df_furto_cel_dp['furto_celular'])
array_furto_cel_dp
# Out:
# array([26230, 25737, 19004, 17630, 16185, 15367, 14842, 14504, 14339,
#        12898, 12278,  8952,  8882,  8754,  8377,  8301,  8192,  7865,
#         7388,  7344,  7074,  6991,  6691,  6657,  6218,  5793,  5692,
#         5625,  5464,  5389,  5070,  4988,  4776,  4768,  4723,  4680,
#         4193,  4150,  4140,  4059,  3891,  3853,  3798,  3770,  3552,
#         3435,  3381,  3301,  3165,  3014,  2992,  2879,  2829,  2726,
#         2618,  2418,  2398,  2366,  2335,  2219,  2168,  2154,  2145,
#         2138,  2097,  1845,  1844,  1831,  1763,  1720,  1670,  1638,
#         1554,  1488,  1476,  1446,  1394,  1386,  1311,  1250,  1154,
#         1096,  1053,  1044,  1041,   941,   836,   824,   812,   752,
#          745,   663,   662,   637,   634,   627,   585,   569,   517,
#          516,   507,   501,   464,   453,   451,   443,   414,   405,
#          387,   376,   369,   362,   357,   304,   303,   261,   245,
# ...

# %%
media = np.mean(array_furto_cel_dp)
mediana = np.median(array_furto_cel_dp)

# %%
print(f'Média {media:.2f}\n Mediana {mediana}')
# Out:
# Média 3554.43
#  Mediana 1741.5

# %% [markdown]
# ## Quartis 100/4 partes de 25%

# %%
media = np.mean(array_furto_cel_dp)
mediana = np.median(array_furto_cel_dp)
q1 = np.percentile(array_furto_cel_dp, 25)
q2 = np.percentile(array_furto_cel_dp,50)
q3 = np.percentile(array_furto_cel_dp,75)
distancia = (media - mediana/mediana)
iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr)
limite_inferior = q1 - (1.5 * iqr)

# %% [markdown]
# ## Outliers (iqr)

# %%
print(f'Média {media:.2f}')
print(f'Mediana {mediana}')
print(f'Q1: {q1}')
print(f'Q2: {q2}')
print(f'Q3: {q3}')
print(f'Distância: {distancia:.2f}')
print(f'Iqr = {iqr}')
print(f'Limite superior : {limite_superior}')
print(f'Limite inferior : {limite_inferior}')
# Out:
# Média 3554.43
# Mediana 1741.5
# Q1: 455.75
# Q2: 1741.5
# Q3: 4712.25
# Distância: 3553.43
# Iqr = 4256.5
# Limite superior : 11097.0
# Limite inferior : -5929.0

# %%
outlier_furto_sup = df_furto_cel_dp.loc[df_furto_cel_dp['furto_celular'] > limite_superior]
outlier_furto_sup
# Out:
#     cisp  furto_celular
# 12    16          26230
# 2      5          25737
# 10    14          19004
# 8     12          17630
# 0      1          16185
# 5      9          15367
# 6     10          14842
# 14    18          14504
# 1      4          14339
# 28    32          12898
# 31    35          12278

# %% [markdown]
# ## Exercício 1

# %%
df_roubo_veic = df.groupby('cisp')['roubo_veiculo'].sum().reset_index()
df_roubo_veic.sort_values(by = 'roubo_veiculo', ascending = False, inplace = True)
df_roubo_veic
# Out:
#      cisp  roubo_veiculo
# 52     59          37866
# 57     64          32892
# 35     39          29753
# 23     27          27978
# 30     34          27596
# ..    ...            ...
# 77     92              8
# 116   140              8
# 115   139              7
# 113   137              6
# 114   138              2
#
# [138 rows x 2 columns]

# %%
array_roubo_veic = np.array(df_roubo_veic['roubo_veiculo'])
array_roubo_veic
# Out:
# array([37866, 32892, 29753, 27978, 27596, 25018, 20742, 20072, 19812,
#        19480, 19448, 18430, 18113, 16977, 16407, 15685, 15202, 15165,
#        14953, 14231, 14005, 12886, 12521, 12144, 12060, 11083, 11080,
#        10813, 10176,  9304,  9136,  8752,  8577,  8576,  8209,  7873,
#         7746,  7377,  7355,  6935,  6481,  5927,  5246,  4699,  4671,
#         4138,  4052,  3889,  3746,  3349,  3274,  2985,  2954,  2787,
#         2769,  2540,  2223,  2148,  2061,  2029,  1960,  1960,  1955,
#         1927,  1501,  1375,  1321,  1291,  1266,  1191,  1060,  1033,
#          972,   936,   790,   777,   760,   661,   583,   502,   483,
#          448,   441,   407,   345,   336,   322,   316,   314,   314,
#          313,   287,   270,   269,   244,   206,   190,   185,   176,
#          174,   152,   130,   107,   103,    93,    91,    87,    80,
#           67,    66,    65,    60,    58,    49,    48,    47,    47,
# ...

# %%
media = np.mean(array_roubo_veic)
mediana = np.median(array_roubo_veic)
q1 = np.percentile(array_roubo_veic,25)
q2 = np.percentile(array_roubo_veic,50) 
q3 = np.percentile(array_roubo_veic,75)

# %%
print(f'Média: {media:.2f}')
print(f'Mediana: {mediana}')
print(f'Q1: {q1}')
print(f'Q2: {q2}')
print(f'Q3: {q3}')
# Out:
# Média: 5260.96
# Mediana: 1228.5
# Q1: 104.0
# Q2: 1228.5
# Q3: 8125.0

# %%
roubo_veic_acima_q3 = df_roubo_veic.loc[df_roubo_veic['roubo_veiculo'] > q3]
roubo_veic_acima_q3
# Out:
#     cisp  roubo_veiculo
# 52    59          37866
# 57    64          32892
# 35    39          29753
# 23    27          27978
# 30    34          27596
# 47    54          25018
# 53    60          20742
# 34    38          20072
# 17    21          19812
# 31    35          19480
# 36    40          19448
# 65    74          18430
# 29    33          18113
# 25    29          16977
# 51    58          16407
# 45    52          15685
# 18    22          15202
# 27    31          15165
# 40    44          14953
# 63    72          14231
# 64    73          14005
# 26    30          12886
# 50    57          12521
# 20    24          12144
# 49    56          12060
# 21    25          11083
# 24    28          11080
# 19    23          10813
# 66    75          10176
# 55    62           9304
# 16    20           9136
# 28    32           8752
# 46    53           8577
# 69    78           8576
# 62    71           8209

# %% [markdown]
# ## Média confiável - distancia

# %%
distancia = (media - mediana)/mediana
print(f'Média precisa: {distancia:.2%}')
# Out:
# Média precisa: 328.24%

# %% [markdown]
# ## Atividade 3

# %%
df_aaapai_dp = df.groupby('cisp')['aaapai'].sum().reset_index()
df_aaapai_dp.sort_values(by = 'aaapai',ascending = False, inplace = True)
df_aaapai_dp
# Out:
#      cisp  aaapai
# 104   126  3736.0
# 8      12  3667.0
# 10     14  3368.0
# 65     74  3355.0
# 12     16  3233.0
# ..    ...     ...
# 130   156    19.0
# 129   155    16.0
# 131   157    14.0
# 94    111    13.0
# 77     92    12.0
#
# [138 rows x 2 columns]

# %%
array_aaapai_dp = np.array(df_aaapai_dp['aaapai'])
array_aaapai_dp
# Out:
# array([3736., 3667., 3368., 3355., 3233., 3042., 2866., 2846., 2755.,
#        2703., 2701., 2312., 2287., 2273., 2143., 2102., 2062., 2051.,
#        1898., 1823., 1817., 1814., 1757., 1694., 1664., 1649., 1638.,
#        1615., 1566., 1554., 1552., 1409., 1367., 1362., 1279., 1277.,
#        1253., 1240., 1217., 1196., 1188., 1143., 1138., 1128., 1117.,
#        1083., 1050., 1029.,  996.,  992.,  940.,  891.,  887.,  885.,
#         878.,  838.,  823.,  807.,  805.,  803.,  788.,  787.,  782.,
#         752.,  745.,  744.,  715.,  703.,  692.,  684.,  636.,  633.,
#         611.,  601.,  592.,  561.,  537.,  518.,  508.,  409.,  396.,
#         394.,  388.,  388.,  353.,  347.,  329.,  327.,  326.,  320.,
#         320.,  318.,  317.,  312.,  311.,  304.,  288.,  288.,  288.,
#         284.,  282.,  275.,  234.,  221.,  204.,  191.,  174.,  172.,
#         163.,  162.,  155.,  142.,  117.,  112.,   95.,   93.,   91.,
# ...

# %%
media = np.mean(array_aaapai_dp)
mediana = np.median(array_aaapai_dp)

# %%
print(f'Média: {media:.2f}')
print(f'Mediana: {mediana}')
# Out:
# Média: 912.99
# Mediana: 688.0

# %%
distancia = (media-mediana)/ mediana
print(f'Margem de erro: {distancia:.2%}')
# Out:
# Margem de erro: 32.70%

# %% [markdown]
# ## Outliers

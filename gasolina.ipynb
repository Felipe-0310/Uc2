# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_2024_1 = pd.read_csv('2024.1.csv', sep=';', decimal=',')
df_2024_2 = pd.read_csv('2024.2.csv', sep=';', decimal=',')
df_2025_1 = pd.read_csv('2025.1.csv', sep=';', decimal=',')
df_2025_2 = pd.read_csv('2025.2.csv', sep=';', decimal=',')
# Out:
# C:\Users\felipe.espirito\AppData\Local\Temp\ipykernel_12504\4053130923.py:3: DtypeWarning: Columns (0: Regiao - Sigla, 1: Estado - Sigla, 2: Municipio, 3: Revenda, 4: CNPJ da Revenda, 5: Nome da Rua, 6: Numero Rua, 7: Complemento, 8: Bairro, 9: Cep, 10: Produto, 11: Data da Coleta, 12: Unidade de Medida, 13: Bandeira) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2025_1 = pd.read_csv('2025.1.csv', sep=';', decimal=',')

# %%
df = pd.concat([df_2024_1, df_2024_2,
 df_2025_1, df_2025_2],
 ignore_index=True)

# %%
df_2024_1 = pd.read_csv('2024.1.csv', sep=';', decimal=',')
df_2024_1
# Out:
#        Regiao - Sigla Estado - Sigla    Municipio  \
# 0                  NE             AL    ARAPIRACA
# 1                  NE             AL    ARAPIRACA
# 2                  NE             AL    ARAPIRACA
# 3                  NE             AL    ARAPIRACA
# 4                  NE             AL    ARAPIRACA
# ...               ...            ...          ...
# 477149              S             PR  CAMPO LARGO
# 477150             NE             MA       CAXIAS
# 477151             NE             MA       CAXIAS
# 477152             NE             MA       CAXIAS
# 477153             NE             MA       CAXIAS
#
#                                                   Revenda  \
# 0       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 1       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 2       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 3       COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...
# 4                           AUTO POSTO SAO FRANCISCO LTDA
# ...

# %%
df_2024_1= df.groupby('Revenda')['Valor de Venda'].mean().reset_index().sort_values(by= 'Valor de Venda',ascending = False)
df_2024_1
# Out:
#                                         Revenda  Valor de Venda
# 6181                L DA COSTA VASCONCELOS LTDA        8.370000
# 7765   POSTO DA PONTE COMERCIO DE PETROLEO LTDA        8.334727
# 4338           CENTRO AUTOMOTIVO GUARUJA 3 LTDA        8.223654
# 5448                         FGN COMERCIAL LTDA        8.223333
# 6364                  M C D CARVALHO & CIA LTDA        8.162628
# ...                                         ...             ...
# 1593             AUTO POSTO ESTACAO LESTE LTDA.        3.926765
# 3407            AUTO POSTO SHALLON ADONAI LTDA.        3.924375
# 7751                              POSTO CS LTDA        3.890000
# 10052            RFL CASTELINHO AUTO POSTO LTDA        3.823333
# 819                       AUTO POSTO BAOBA LTDA        3.790000
#
# [10951 rows x 2 columns]

# %%
array_posto_241 = np.array(df_2024_1['Valor de Venda'])
array_posto_241
# Out:
# array([8.37      , 8.33472727, 8.22365385, ..., 3.89      , 3.82333333,
#        3.79      ], shape=(10951,))

# %%
media = np.mean(array_posto_241)
mediana = np.median(array_posto_241)
